# %% [markdown]
# # Analysis on interntional turism

# %% [markdown]
# ## Load libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Set seaborn theme for the graphs
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params, palette='pastel')

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('API_ST.INT.ARVL_DS2_es_csv_v2_32197/API_ST.INT.ARVL_DS2_es_csv_v2_32197.csv')

# %%
data.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Turismo internacional, número de arribos
# 1          NaN          AFE  Turismo internacional, número de arribos
# 2   Afganistán          AFG  Turismo internacional, número de arribos
# 3          NaN          AFW  Turismo internacional, número de arribos
# 4       Angola          AGO  Turismo internacional, número de arribos
#
#   Indicator Code  1960  1961  1962  1963  1964  1965  ...          2014  \
# 0    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.739000e+06
# 1    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  3.573839e+07
# 2    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 3    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.054462e+07
# 4    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.950000e+05
#
#            2015          2016          2017          2018          2019  2020  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            0 non-null      float64
#  5   1961            0 non-null      float64
#  6   1962            0 non-null      float64
#  7   1963            0 non-null      float64
#  8   1964            0 non-null      float64
#  9   1965            0 non-null      float64
#  10  1966            0 non-null      float64
#  11  1967            0 non-null      float64
#  12  1968            0 non-null      float64
#  13  1969            0 non-null      float64
#  14  1970            0 non-null      float64
#  15  1971            0 non-null      float64
#  16  1972            0 non-null      float64
# ...

# %% [markdown]
# As we can see there are a lot of years with all NaN or null values that we might omit to don't care of it.

# %%
wdata = data.copy()

wdata.dropna(axis='columns', how='all')

wdata.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Turismo internacional, número de arribos
# 1          NaN          AFE  Turismo internacional, número de arribos
# 2   Afganistán          AFG  Turismo internacional, número de arribos
# 3          NaN          AFW  Turismo internacional, número de arribos
# 4       Angola          AGO  Turismo internacional, número de arribos
#
#   Indicator Code  1960  1961  1962  1963  1964  1965  ...          2014  \
# 0    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.739000e+06
# 1    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  3.573839e+07
# 2    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 3    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.054462e+07
# 4    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.950000e+05
#
#            2015          2016          2017          2018          2019  2020  \
# ...
